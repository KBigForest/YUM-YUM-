# %%
import pandas as pd

# %%
test_df = pd.read_csv('광주.csv')

# %%
test_df['업종'].unique()[test_df['업종'].value_counts()]
# Out:
# array(['분식', '두부전문점', '국밥', '베트남음식', '커피전문점', '돈까스,우동', '돈까스,우동', '카페',
#        '카페', '카페', '호프,요리주점', '호프,요리주점', '한정식', '한정식', '아웃백스테이크하우스',
#        '아웃백스테이크하우스', '아웃백스테이크하우스', '육류,고기', '육류,고기', '육류,고기', '육류,고기',
#        '육류,고기', '곱창,막창', '곱창,막창', '곱창,막창', '양식', '양식', '양식', '양식', '삼겹살',
#        '삼겹살', '삼겹살', '삼겹살', '삼겹살', '삼겹살', '삼겹살', '삼겹살', '삼겹살', '삼겹살',
#        '삼겹살', '삼겹살', '삼겹살', '삼겹살', '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식',
#        '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식',
#        '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식', '퓨전한식'], dtype=object)

# %%
test_df
# Out:
#      Unnamed: 0                      영업 시간           가게명
# 0           297          화~일 12:00 ~ 20:30        람바다 본점  \
# 1           142           매일 11:30 ~ 20:30    행복한임금님 수완점
# 2           154           매일 16:00 ~ 23:00      식당미생 상무점
# 3           209          화~일 11:30 ~ 20:30       그라제1985
# 4           130          월~토 17:00 ~ 00:30         팔팔소곱창
# ..          ...                        ...           ...
# 305         114  월,수,목,금,토,일 11:00 ~ 20:00        꽃피는춘삼월
# 306          93          화~일 11:30 ~ 22:00  정광석항아리보쌈 첨단점
# 307         138           매일 10:00 ~ 23:00           시골집
# 308         155           매일 11:00 ~ 22:00            닭꿈
# 309          48           매일 09:30 ~ 21:30           상무옥
#
#                                               가게 주소     업종
# 0                             광주 북구 갈마로 57 (우)61161      회  \
# 1                        광주 광산구 왕버들로 113-2 (우)62245   퓨전한식
# 2                       광주 서구 상무평화로 101 1층 (우)61963    삼겹살
# ...
